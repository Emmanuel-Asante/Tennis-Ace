# %%
# Import modules
#import codecademylib3_seaborn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
from scipy.stats import pearsonr

# %%
# load and investigate the data here:

# Load data into a dataframe
df = pd.read_csv("tennis_stats.csv")

# Inspect dataframe
df.head()
# Out:
#                  Player  Year  FirstServe  FirstServePointsWon  \
# 0           Pedro Sousa  2016        0.88                 0.50
# 1       Roman Safiullin  2017        0.84                 0.62
# 2           Pedro Sousa  2017        0.83                 0.60
# 3   Rogerio Dutra Silva  2010        0.83                 0.64
# 4  Daniel Gimeno-Traver  2017        0.81                 0.54
#
#    FirstServeReturnPointsWon  SecondServePointsWon  \
# 0                       0.38                  0.50
# 1                       0.26                  0.33
# 2                       0.28                  0.53
# 3                       0.34                  0.59
# 4                       0.00                  0.33
#
#    SecondServeReturnPointsWon  Aces  BreakPointsConverted  BreakPointsFaced  \
# 0                        0.39     0                  0.14                 7
# 1                        0.07     7                  0.00                 7
# ...

# %%
# perform exploratory analysis here:

# Create a function
def exploratory_analysis_winnings():
    # Create list of game features
    game = ['Aces', 'DoubleFaults', 'FirstServe', 'FirstServePointsWon', 'SecondServePointsWon', 'BreakPointsFaced',
            'BreakPointsSaved', 'ServiceGamesPlayed', 'ServiceGamesWon', 'TotalServicePointsWon', 'FirstServeReturnPointsWon',
           'SecondServeReturnPointsWon', 'BreakPointsOpportunities', 'BreakPointsConverted', 'ReturnGamesPlayed', 'ReturnGamesWon',
           'ReturnPointsWon', 'TotalPointsWon']
    # Create an empty dictionary
    corr_dict = {}
    # Iterate through game feature list
    for item in game:
        # Create a scatter plot of a feature vs. 'Winnings'
        sns.scatterplot(x=df[item], y=df['Winnings'])
        # Create plot title
        plt.title(item + ' vs. Winnings')
        # Show plot
        plt.show()
        # Calculate correlation coefficient
        corr, p = pearsonr(df[item], df['Winnings'])
        # Update corr_dict with a game feature and its corresponding correlation coefficient
        corr_dict[item] = corr
        # Output corr
        print('The correlation between ' + item + ' and Winnings is ' + str(corr))
        # Clear current plot
        plt.clf()
    # Output corr_dict
    print(corr_dict)
    # Get the highest correlation coefficient with its corresponding game feature
    itemMaxValue = max(corr_dict.items(), key=lambda x : x[1])
    # Output correlation coefficient
    print('\nHeighest correlation coefficient between a feature and Winnings: ', itemMaxValue[1])
    # Output game feature
    print('Feature: ', itemMaxValue[0])
    
    
# Create a function    
def exploratory_analysis_losses():
    # Create list of game features
    game = ['Aces', 'DoubleFaults', 'FirstServe', 'FirstServePointsWon', 'SecondServePointsWon', 'BreakPointsFaced',
            'BreakPointsSaved', 'ServiceGamesPlayed', 'ServiceGamesWon', 'TotalServicePointsWon', 'FirstServeReturnPointsWon',
           'SecondServeReturnPointsWon', 'BreakPointsOpportunities', 'BreakPointsConverted', 'ReturnGamesPlayed', 'ReturnGamesWon',
           'ReturnPointsWon', 'TotalPointsWon']
    # Create an empty dictionary
    corr_dict = {}
    # Iterate through game feature list
    for item in game:
        # Create a scatter plot of a feature vs. 'Winnings'
        sns.scatterplot(x=df[item], y=df['Losses'])
        # Create plot title
        plt.title(item + ' vs. Losses')
        # Show plot
        plt.show()
        # Calculate correlation coefficient
        corr, p = pearsonr(df[item], df['Losses'])
        # Update corr_dict with a game feature and its corresponding correlation coefficient
        corr_dict[item] = corr
        # Output corr
        print('The correlation between ' + item + ' and Losses is ' + str(corr))
        # Clear current plot
        plt.clf()
    # Output corr_dict
    print(corr_dict)
    # Get the highest correlation coefficient with its corresponding game feature
    itemMaxValue = max(corr_dict.items(), key=lambda x : x[1])
    # Output correlation coefficient
    print('\nHeighest correlation coefficient between a feature and Losses: ', itemMaxValue[1])
    # Output game feature
    print('feature: ', itemMaxValue[0])

# %%
# Function call
exploratory_analysis_winnings()
# Out:
# The correlation between Aces and Winnings is 0.7984043540699396
# The correlation between DoubleFaults and Winnings is 0.8546851784438951
# The correlation between FirstServe and Winnings is 0.05788214662085265
# The correlation between FirstServePointsWon and Winnings is 0.3611210594929001
# The correlation between SecondServePointsWon and Winnings is 0.2812148088288471
# The correlation between BreakPointsFaced and Winnings is 0.8760356989199041
# The correlation between BreakPointsSaved and Winnings is 0.2582707718865993
# The correlation between ServiceGamesPlayed and Winnings is 0.9129849378413316
# The correlation between ServiceGamesWon and Winnings is 0.3955771739851861
# The correlation between TotalServicePointsWon and Winnings is 0.4077070018393828
# The correlation between FirstServeReturnPointsWon and Winnings is 0.24080834046115251
# The correlation between SecondServeReturnPointsWon and Winnings is 0.1994012973607896
# ...

# %%
# Function call
exploratory_analysis_losses()
# Out:
# The correlation between Aces and Losses is 0.7686283347845062
# The correlation between DoubleFaults and Losses is 0.8819221007707447
# The correlation between FirstServe and Losses is 0.05373605107760283
# The correlation between FirstServePointsWon and Losses is 0.33058098979961836
# The correlation between SecondServePointsWon and Losses is 0.2509178795903475
# The correlation between BreakPointsFaced and Losses is 0.9433086885312026
# The correlation between BreakPointsSaved and Losses is 0.2469895922555547
# The correlation between ServiceGamesPlayed and Losses is 0.9351823440696606
# The correlation between ServiceGamesWon and Losses is 0.36734476286223494
# The correlation between TotalServicePointsWon and Losses is 0.3712825143021403
# The correlation between FirstServeReturnPointsWon and Losses is 0.2432784787577652
# The correlation between SecondServeReturnPointsWon and Losses is 0.18521712388123296
# ...

# %%
# Analysis from the above scatter plot
print("There exist a strong positive relationship between ServiceGamesPlayed feature and Winnings outcome")
# Out:
# There exist a strong positive relationship between ServiceGamesPlayed feature and Winnings outcome

# %%
## perform single feature linear regressions here:

# Select FirstServeReturnPointsWon feature
features = df[['FirstServeReturnPointsWon']]

# Select winning outcome
outcome = df[['Winnings']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Winnings with BreakPointsOpportunities Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Create a scatter plot of predicted vs. outcome_test
plt.scatter(outcome_test, prediction, alpha=0.4)

# Show plot
plt.show()
# Out:
# Predicting Winnings with BreakPointsOpportunities Test Score: 0.0703888834155888

# %%
## perform two feature linear regressions here:

# Clear current plot
plt.clf()

# Select ServiceGamesPlayed feature
features = df[['ServiceGamesPlayed']]

# Select winning outcome
outcome = df[['Winnings']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Winnings with ServiceGamesPlayed Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Create a scatter plot of predicted vs. outcome_test
plt.scatter(outcome_test, prediction, alpha=0.4)

# Show plot
plt.show()

# Clear current plot
plt.clf()

# Select BreakPointsOpportunities feature
features = df[['BreakPointsOpportunities']]

# Select winning outcome
outcome = df[['Winnings']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Winnings with BreakPointsOpportunities Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Create a scatter plot of predicted vs. outcome_test
plt.scatter(outcome_test, prediction, alpha=0.4)

# Show plot
plt.show()

# Clear current plot
plt.clf()



# Select BreakPointsFaced feature
features = df[['BreakPointsFaced']]

# Select lossing outcome
outcome = df[['Losses']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Losses with BreakPointsFaced Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Create a scatter plot of predicted vs. outcome_test
plt.scatter(outcome_test, prediction, alpha=0.4)

# Show plot
plt.show()

# Findings
print("It was found that the best single feature linear regression model came from using \
'ServiceGamesPlayed' or 'BreakPointsOpportunities' as the feature to predict 'Winnings', or using \
'BreakPointsFaced' as the feature to predict 'Losses'.")
# Out:
# Predicting Winnings with ServiceGamesPlayed Test Score: 0.771262384151451
# Predicting Winnings with BreakPointsOpportunities Test Score: 0.8242997909128993
# Predicting Losses with BreakPointsFaced Test Score: 0.8866549368770438
# It was found that the best single feature linear regression model came from using 'ServiceGamesPlayed' or 'BreakPointsOpportunities' as the feature to predict 'Winnings', or using 'BreakPointsFaced' as the feature to predict 'Losses'.

# %%
## perform multiple feature linear regressions here:

# Select features
features = df[['BreakPointsOpportunities', 'FirstServeReturnPointsWon']]

# Select 'Winnings' outcome
outcome = df[['Winnings']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Winnings with Multiple Features Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Clear current plot
plt.clf()

# Create a scatter plot of predictions against actual outcome (winnings)
plt.scatter(outcome_test, prediction, alpha=0.4)

# Set plot title
plt.title('Predicted Winnings vs. Actual Winnings - Multiple Features')

# Set x-axis label
plt.xlabel('Actual Winnings')

# Set y-axis label
plt.ylabel('Predicted Winnings')

# Show plot
plt.show()
# Out:
# Predicting Winnings with Multiple Features Test Score: 0.8099999421890635

# %%
# Select features
features = df[['FirstServe','FirstServePointsWon','FirstServeReturnPointsWon',
'SecondServePointsWon','SecondServeReturnPointsWon','Aces',
'BreakPointsConverted','BreakPointsFaced','BreakPointsOpportunities',
'BreakPointsSaved','DoubleFaults','ReturnGamesPlayed','ReturnGamesWon',
'ReturnPointsWon','ServiceGamesPlayed','ServiceGamesWon','TotalPointsWon',
'TotalServicePointsWon']]

# Select 'Winnings' outcome
outcome = df[['Winnings']]

# Split data into training and test sets
features_train, features_test, outcome_train, outcome_test = train_test_split(features, outcome, train_size = 0.8, test_size = 0.2)

# Create a linear regression model
model = LinearRegression()

# Train model on training data
model.fit(features_train, outcome_train)

# Score model on test data
print('Predicting Winnings with Multiple Features Test Score:', model.score(features_test, outcome_test))

# Find predicted outcome
prediction = model.predict(features_test)

# Clear current plot
plt.clf()

# Create a scatter plot of predictions against actual outcome (winnings)
plt.scatter(outcome_test, prediction, alpha=0.4)

# Set plot title
plt.title('Predicted Winnings vs. Actual Winnings - Multiple Features')

# Set x-axis label
plt.xlabel('Actual Winnings')

# Set y-axis label
plt.ylabel('Predicted Winnings')

# Show plot
plt.show()
# Out:
# Predicting Winnings with Multiple Features Test Score: 0.8234768919686996
